# %% [markdown]
# # Sprint 1: Exploratory Data Analysis
#
# **AI for Equitable Public Transportation** — Miami-Dade County
#
# ## Objectives
# - Profile and assess data quality (shape, types, missingness, distributions)
# - Evaluate geographic compatibility across datasets
# - Visualize transit coverage vs. population density
# - Identify access disparities and formulate hypotheses for modeling
#
# ## Data Sources
# 1. US Census Bureau (ACS 2023) — `data/raw/census/`
# 2. GTFS Schedule & Real-Time — `data/raw/gtfs/`
# 3. National Accessibility Evaluation — `data/raw/accessibility/`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Optional: geographic
# import geopandas as gpd
# import folium

pd.set_option('display.max_columns', 50)
sns.set_theme(style='whitegrid')

print('Setup complete ✓')

# %% [markdown]
# ## 1. Data Acquisition & Profiling (Sub-Sprint 1a)
#
# ### 1.1 Census Data

# %%
# TODO: Load Census ACS data
# census_df = pd.read_csv('../data/raw/census/acs_2023.csv')
# census_df.info()
# census_df.describe()

# %% [markdown]
# ### 1.2 GTFS Data

# %%
# TODO: Load GTFS schedule data
# stops = pd.read_csv('../data/raw/gtfs/stops.txt')
# routes = pd.read_csv('../data/raw/gtfs/routes.txt')
# stop_times = pd.read_csv('../data/raw/gtfs/stop_times.txt')

# %% [markdown]
# ### 1.3 Accessibility Data

# %%
# TODO: Load National Accessibility Evaluation data

# %% [markdown]
# ## 2. Data Quality Assessment
#
# **Decision Gate Questions (Jan 30):**
# - Do geographic levels match (ZIP, tract, block group)?
# - Is there enough coverage for Miami-Dade County?
# - Are there critical gaps requiring alternative sources?

# %%
# TODO: Missingness analysis
# TODO: Geographic coverage check
# TODO: Data type validation

# %% [markdown]
# ## 3. Exploratory Visualizations (Sub-Sprint 1c)
#
# - Transit coverage vs. population density
# - Access disparities (wait times, service frequency, stop coverage)
# - Correlation analysis

# %%
# TODO: Maps, distributions, correlations

# %% [markdown]
# ## 4. Key Findings & Hypotheses
#
# | Finding | Hypothesis | Implication |
# |---------|-----------|-------------|
# | TBD | TBD | TBD |
